# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import load_iris
data = load_iris(as_frame=True).frame

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
labels = data.drop("target",axis=1)
targets = data["target"]

X_train, X_test, y_train, y_test = train_test_split(labels, targets, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

clf = DecisionTreeClassifier(
    max_depth=3,
    min_samples_split=4,
    random_state=42
)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_split=4, random_state=42)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plot_tree(
    clf,
    feature_names=labels.columns.to_list(),
    class_names=[str(c) for c in sorted(targets.unique())],
    filled=True
)
plt.show()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

y_pred = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Accuracy:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Accuracy:
#  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
